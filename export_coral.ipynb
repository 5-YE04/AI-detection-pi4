# %%
# Export YOLO11n for Google Coral Edge TPU
# !pip install ultralytics

from ultralytics import YOLO

# Download YOLO11n (or change to yolo11s.pt / yolo11m.pt)
# !wget https://github.com/ultralytics/assets/releases/download/v0.0.0/yolo11n.pt

model = YOLO('yolo11n.pt')
# Adjust imgsz as needed: 224, 320, 416, 640
model.export(format='edgetpu', imgsz=320)

from google.colab import files
files.download('yolo11n_saved_model/yolo11n_full_integer_quant_edgetpu.tflite')
